# %%
# Market Analytics allow for data greater than 2 weeks but looks like it aggreates all new listings, 
import os

# %%
item_id = "WolfPelt"
condense,has_sold = True,True
interval = '3m'
start,end = '2025-10-07','2025-10-08'
limit,page = '50','1'

url = (
    f'https://api.darkerdb.com/v1/market/analytics/{item_id}/prices/history'
    f'?key={os.getenv("dark_api_key")}'
    f'&interval={interval}'
    f'&from={start}&to={end}'
)

url
# Out:
# 'https://api.darkerdb.com/v1/market/analytics/WolfPelt/prices/history?key=meowlin&interval=3m&from=2025-10-07&to=2025-10-08'
