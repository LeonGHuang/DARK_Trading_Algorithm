# %%
import src.database.scripts.sql as sql 

import requests
from datetime import datetime, timedelta, timezone
import numpy as np
import aiohttp
import asyncio

# %%
def sql_item():
    conn = sql.connect_pc()
    cursor = conn.cursor()
    query = """
        SELECT name, rarity, vendor_price FROM item_data
        WHERE type NOT IN ('Armor', 'Weapon', 'Accessory')
        AND vendor_price > 49
        ORDER BY vendor_price DESC
        """
    cursor.execute(query)
    return cursor.fetchall()


async def fetch(session, conn_limit, name, rarity, vendor_price):
    async with conn_limit:
        from_date = (datetime.now(timezone.utc) - timedelta(minutes=15)).strftime("%Y-%m-%dT%H:%M:%SZ")
        url = f"https://api.darkerdb.com/v1/market?item={name.replace('\'', "'")}&rarity={rarity}&from={from_date}&limit=50&sold=0"
        response = await session.get(url)
        output = await response.json()
        response.release()

    items = [(listing['price_per_unit'], listing['quantity']) for listing in output['body']]
    undercut_items = list(filter(lambda x: x[0] < vendor_price, items))
    extractable_value = round(sum((vendor_price - x[0]) * x[1] for x in undercut_items))
    average_undercut_price = int(np.mean([x[0] for x in undercut_items])) if undercut_items else 0
    average_margin = (vendor_price - average_undercut_price) if average_undercut_price else 0
    undercut_quantity = round(sum([x[1] for x in undercut_items]))

    return (name, extractable_value, vendor_price, average_margin, undercut_quantity, undercut_items)


async def main(sem_limit):
    header = [('name', 'extractable', 'vendor_price', 'avg_margin', 'quantity', 'listings')]

    sem = asyncio.Semaphore(sem_limit)
    async with aiohttp.ClientSession() as session:
        task = [fetch(session, sem, name, rarity, vendor_price) for name, rarity, vendor_price in sql_item()]
        rows = await asyncio.gather(*task)

    return header + list(rows)

# %%
if __name__ == '__main__':
    rows = await main(50)

    rows[1:] = sorted(rows[1:], key=lambda x: x[1], reverse=True)
    for x in rows:
        print(f"{x[0]:<35} {x[1]:>15} {x[2]:>20} {x[3]:>20} {x[4]:>20} {x[5]}")
# Out:
# name                                    extractable         vendor_price           avg_margin             quantity listings
# Emerald (Perfect)                               203                   50                   11                   20 [(49.67, 3), (41, 1), (40.67, 3), (32, 1), (37, 3), (37, 3), (37, 3), (40, 3)]
# Gold Bowl (Royal)                               110                  400                   55                    2 [(390, 1), (300, 1)]
# Gold Bowl (Perfect)                              95                  200                   19                    5 [(180, 1), (180, 1), (180, 1), (190, 1), (175, 1)]
# Chronicles of the Cursed Crown                   85                  500                   43                    2 [(455, 1), (460, 1)]
# Ancient Scroll (Exquisite)                       79                  150                   16                    5 [(130, 1), (130, 1), (140, 1), (138, 1), (133, 1)]
# Gold Waterpot (Perfect)                          57                  200                   19                    3 [(180, 1), (175, 1), (188, 1)]
# Cave Trolls Precious Rock                        50                  500                   50                    1 [(450, 1)]
# Gold Chalice (Perfect)                           41                  100                   41                    1 [(59, 1)]
# Ancient Scroll (Perfect)                         37                  300                   13                    3 [(285, 1), (290, 1), (288, 1)]
# Gold Chalice (Exquisite)                         35                   50                   18                    2 [(20, 1), (45, 1)]
# Ceremonial Dagger (Royal)                        23                  200                   23                    1 [(177, 1)]
# Diary of the Toz                                 22                  500                   11                    2 [(498, 1), (480, 1)]
# Gold Crown (Perfect)                             15                  200                    8                    2 [(190, 1), (195, 1)]
# Centaur Hoof                                     15                  200                   15                    1 [(185, 1)]
# Gold Goblet (Exquisite)                          15                   50                    5                    3 [(45, 1), (45, 1), (45, 1)]
# Gold Candelabra (Royal)                          12                  400                   12                    1 [(388, 1)]
# Twisted Abyss Horn                               12                  112                   12                    1 [(100, 1)]
# Wendigo's Antler Fragment                        10                  200                   10                    1 [(190, 1)]
# Light Gold Bangle (Perfect)                       8                   50                    4                    2 [(47, 1), (45, 1)]
# Gold Band (Perfect)                               5                   50                    5                    1 [(45, 1)]
# Emerald (Royal)                                   3                  100                    1                    6 [(99, 1), (99.67, 3), (99.5, 2)]
# Shine Bangle (Perfect)                            3                   50                    3                    1 [(47, 1)]
# Goblet (Exquisite)                                3                   50                    3                    1 [(47, 1)]
# Corrupted Heart                                   0                30000                    0                    0 []
# Head of the Midnight Stag                         0                20000                    0                    0 []
# Frost Wyvern Egg                                  0                10000                    0                    0 []
# Ancient Stingray Egg                              0                10000                    0                    0 []
# Crown of the Midnight Stag                        0                10000                    0                    0 []
# Intricate Wooden Figurine                         0                 5000                    0                    0 []
# Chocolate Chip Muffin                             0                 5000                    0                    0 []
# Honeybliss Pear                                   0                 5000                    0                    0 []
# Cursed Bell                                       0                 1700                    0                    0 []
# Ancient Scroll (Ultimate)                         0                 1050                    0                    0 []
# Seal of Dominion                                  0                 1000                    0                    0 []
# Gold Candle Holder (Ultimate)                     0                  700                    0                    0 []
# Gold Waterpot (Ultimate)                          0                  700                    0                    0 []
# Gold Crown (Ultimate)                             0                  700                    0                    0 []
# Gold Candelabra (Ultimate)                        0                  700                    0                    0 []
# Gold Bowl (Ultimate)                              0                  700                    0                    0 []
# Ancient Scroll (Royal)                            0                  600                    0                    0 []
# Tear of the Volcano                               0                  500                    0                    0 []
# Wanderlight Lantern                               0                  500                    0                    0 []
# Breath of the Deceased                            0                  500                    0                    0 []
# Manuscripts of the Warlord                        0                  500                    0                    0 []
# Broken War Horn                                   0                  500                    0                    0 []
# Skull Key                                         0                  500                    0                    0 []
# Frostbitten Mallet                                0                  500                    0                    0 []
# Cyclops Precious Mirror                           0                  500                    0                    0 []
# Ship's Wheel                                      0                  450                    0                    0 []
# Gold Waterpot (Royal)                             0                  400                    0                    0 []
# Troll's Club                                      0                  400                    0                    0 []
# Cyclops’s Club                                    0                  400                    0                    0 []
# Gold Crown (Royal)                                0                  400                    0                    0 []
# Gold Candle Holder (Royal)                        0                  400                    0                    0 []
# Goblet (Ultimate)                                 0                  350                    0                    0 []
# Warped Adamantine Shackles                        0                  350                    0                    0 []
# Saltvine                                          0                  350                    0                    0 []
# Gold Goblet (Ultimate)                            0                  350                    0                    0 []
# Ceremonial Dagger (Ultimate)                      0                  350                    0                    0 []
# Spectral Fabric                                   0                  350                    0                    0 []
# Wardweed                                          0                  350                    0                    0 []
# Lifeleaf                                          0                  350                    0                    0 []
# Phantom Flower                                    0                  350                    0                    0 []
# Silver Chalice (Ultimate)                         0                  350                    0                    0 []
# Gold Chalice (Ultimate)                           0                  350                    0                    0 []
# Troll Pelt                                        0                  350                    0                    0 []
# Torn Wing Fragment                                0                  321                    0                    0 []
# Warlord's Broken Sword Blade                      0                  300                    0                    0 []
# Scroll of Lost Names                              0                  300                    0                    0 []
# Anchor                                            0                  300                    0                    0 []
# Scroll of Sealed Curse                            0                  300                    0                    0 []
# Scroll of Faded Shadows                           0                  300                    0                    0 []
# Scroll of Forgotten Knowledge                     0                  300                    0                    0 []
# Goat Hide Rug                                     0                  300                    0                    0 []
# Scroll of Vanished Memories                       0                  300                    0                    0 []
# Spectral Hilt                                     0                  250                    0                    0 []
# Shining Pearl                                     0                  250                    0                    0 []
# Cockatrice’s Egg                                  0                  250                    0                    0 []
# Cockatrice’s Lucky Feather                        0                  250                    0                    0 []
# Bone Powder                                       0                  250                    0                    0 []
# Goblet (Royal)                                    0                  200                    0                    0 []
# Gold Candle Holder (Perfect)                      0                  200                    0                    0 []
# Dog Collar                                        0                  200                    0                    0 []
# Silver Chalice (Royal)                            0                  200                    0                    0 []
# Gold Candelabra (Perfect)                         0                  200                    0                    0 []
# Gold Chalice (Royal)                              0                  200                    0                    0 []
# Phantom Flower                                    0                  200                    0                    0 []
# Cyclops Eye                                       0                  200                    0                    0 []
# Cursed Crown                                      0                  200                    0                    0 []
# Frost Wyvern's Claws                              0                  200                    0                    0 []
# White Shark Fin                                   0                  200                    0                    0 []
# Frost Wyvern's Hide                               0                  200                    0                    0 []
# Thick Forefoot                                    0                  200                    0                    0 []
# Frozen Heart                                      0                  200                    0                    0 []
# Wardweed                                          0                  200                    0                    0 []
# Lifeleaf                                          0                  200                    0                    0 []
# Gold Goblet (Royal)                               0                  200                    0                    0 []
# Human Remains                                     0                  200                    0                    0 []
# Centaur Horn                                      0                  200                    0                    0 []
# Giant Horn                                        0                  200                    0                    0 []
# Saltvine                                          0                  200                    0                    0 []
# Lute                                              0                  180                    0                    0 []
# Diamond (Ultimate)                                0                  175                    0                    0 []
# Blue Sapphire (Ultimate)                          0                  175                    0                    0 []
# Emerald (Ultimate)                                0                  175                    0                    0 []
# Patterned Gold Bangle (Ultimate)                  0                  175                    0                    0 []
# Gold Band (Ultimate)                              0                  175                    0                    0 []
# Lava Mushroom                                     0                  175                    0                    0 []
# Pearl Necklace (Ultimate)                         0                  175                    0                    0 []
# Ruby (Ultimate)                                   0                  175                    0                    0 []
# Gem Necklace (Ultimate)                           0                  175                    0                    0 []
# Leaf Gold Bangle (Ultimate)                       0                  175                    0                    0 []
# Gold Candle Platter (Ultimate)                    0                  175                    0                    0 []
# Gem Ring (Ultimate)                               0                  175                    0                    0 []
# Slim Bangle (Ultimate)                            0                  175                    0                    0 []
# Shine Bangle (Ultimate)                           0                  175                    0                    0 []
# Simple Gold Bangle (Ultimate)                     0                  175                    0                    0 []
# Dotted Gold Bangle (Ultimate)                     0                  175                    0                    0 []
# Turquoise Gem Bangle (Ultimate)                   0                  175                    0                    0 []
# Arcane Essence                                    0                  175                    0                    0 []
# Light Gold Bangle (Ultimate)                      0                  175                    0                    0 []
# Triple Gem Bangle (Ultimate)                      0                  175                    0                    0 []
# Glimmer Bangle (Ultimate)                         0                  175                    0                    0 []
# Birdcage                                          0                  150                    0                    0 []
# Golden Key                                        0                  150                    0                    0 []
# Broken Pickaxe                                    0                  150                    0                    0 []
# Armillary Sphere                                  0                  150                    0                    0 []
# Frozen Iron Key                                   0                  150                    0                    0 []
# Sturdy Log                                        0                  150                    0                    0 []
# Battle-Worn Armor Fragment                        0                  142                    0                    0 []
# Froststone Ore                                    0                  125                    0                    0 []
# Froststone Ingot                                  0                  125                    0                    0 []
# Froststone Powder                                 0                  125                    0                    0 []
# Gold Ingot                                        0                  125                    0                    0 []
# Gold Ore                                          0                  125                    0                    0 []
# Gold Powder                                       0                  125                    0                    0 []
# Rubysilver Powder                                 0                  125                    0                    0 []
# Rubysilver Ore                                    0                  125                    0                    0 []
# Rubysilver Ingot                                  0                  125                    0                    0 []
# Obsidian Ingot                                    0                  125                    0                    0 []
# Obsidian Ore                                      0                  125                    0                    0 []
# Obsidian Powder                                   0                  125                    0                    0 []
# Lava Golem Shoulder Fragment                      0                  120                    0                    0 []
# Lute                                              0                  120                    0                    0 []
# Blazing Tail                                      0                  120                    0                    0 []
# Lyre                                              0                  120                    0                    0 []
# Drum                                              0                  120                    0                    0 []
# Broken Wooden Barrel Fragment                     0                  108                    0                    0 []
# Hell Hunter's Curved Blade                        0                  103                    0                    0 []
# Gem Ring (Royal)                                  0                  100                    0                    0 []
# Smelly Vomit                                      0                  100                    0                    0 []
# Gold Goblet (Perfect)                             0                  100                    0                    0 []
# Gem Necklace (Royal)                              0                  100                    0                    0 []
# Phantom Flower                                    0                  100                    0                    0 []
# Scabbard                                          0                  100                    0                    0 []
# Sticky Tongue                                     0                  100                    0                    0 []
# Gold Crown (Exquisite)                            0                  100                    0                    0 []
# Flame Gas Bag                                     0                  100                    0                    0 []
# Sturdy Rope                                       0                  100                    0                    0 []
# Extra Thick Pelt                                  0                  100                    0                    0 []
# Banshee Sonnet                                    0                  100                    0                    0 []
# Arcane Essence                                    0                  100                    0                    0 []
# Gold Waterpot (Exquisite)                         0                  100                    0                    0 []
# Doctor's Bag                                      0                  100                    0                    0 []
# Diamond (Royal)                                   0                  100                    0                    0 []
# Warlord's Armor Shard                             0                  100                    0                    0 []
# Saltvine                                          0                  100                    0                    0 []
# Tidestone Ingot                                   0                  100                    0                    0 []
# Sailor's Journal                                  0                  100                    0                    0 []
# Wardweed                                          0                  100                    0                    0 []
# Tidestone Ore                                     0                  100                    0                    0 []
# Blue Sapphire (Royal)                             0                  100                    0                    0 []
# Iron Chain                                        0                  100                    0                    0 []
# Tidestone Powder                                  0                  100                    0                    0 []
# Mysterious Potion                                 0                  100                    0                    0 []
# Cyclops Rags                                      0                  100                    0                    0 []
# Turquoise Gem Bangle (Royal)                      0                  100                    0                    0 []
# Dotted Gold Bangle (Royal)                        0                  100                    0                    0 []
# Gold Candle Holder (Exquisite)                    0                  100                    0                    0 []
# Simple Gold Bangle (Royal)                        0                  100                    0                    0 []
# Gold Band (Royal)                                 0                  100                    0                    0 []
# Patterned Gold Bangle (Royal)                     0                  100                    0                    0 []
# Giant Bat Hide                                    0                  100                    0                    0 []
# Gold Candle Platter (Royal)                       0                  100                    0                    0 []
# Goblet (Perfect)                                  0                  100                    0                    0 []
# Glimmer Bangle (Royal)                            0                  100                    0                    0 []
# Shine Bangle (Royal)                              0                  100                    0                    0 []
# Slim Bangle (Royal)                               0                  100                    0                    0 []
# Gold Bowl (Exquisite)                             0                  100                    0                    0 []
# Leaf Gold Bangle (Royal)                          0                  100                    0                    0 []
# Triple Gem Bangle (Royal)                         0                  100                    0                    0 []
# Light Gold Bangle (Royal)                         0                  100                    0                    0 []
# Gold Candelabra (Exquisite)                       0                  100                    0                    0 []
# Silver Chalice (Perfect)                          0                  100                    0                    0 []
# Core of Cinder                                    0                  100                    0                    0 []
# Ceremonial Dagger (Perfect)                       0                  100                    0                    0 []
# Pearl Necklace (Royal)                            0                  100                    0                    0 []
# Lava Mushroom                                     0                  100                    0                    0 []
# Bug Shell                                         0                  100                    0                    0 []
# Ruby (Royal)                                      0                  100                    0                    0 []
# Lifeleaf                                          0                  100                    0                    0 []
# Broom                                             0                  100                    0                    0 []
# Broken Wheel                                      0                  100                    0                    0 []
# Wendigo's Entrails                                0                  100                    0                    0 []
# Broken Frame                                      0                  100                    0                    0 []
# Rotten Lump                                       0                  100                    0                    0 []
# Flute                                             0                   90                    0                    0 []
# Misshapen Blade Shard                             0                   87                    0                    0 []
# Lyre                                              0                   80                    0                    0 []
# Mystical Gem                                      0                   80                    0                    0 []
# Drum                                              0                   80                    0                    0 []
# Demon Dog Thorn                                   0                   75                    0                    0 []
# Centaur Tail                                      0                   75                    0                    0 []
# Token of Honor                                    0                   75                    0                    0 []
# Cracked Log                                       0                   75                    0                    0 []
# Broken Bone Spike                                 0                   75                    0                    0 []
# Ancient Scroll (Normal)                           0                   72                    0                    0 []
# Woven Rattan Bottle                               0                   72                    0                    0 []
# Lute                                              0                   72                    0                    0 []
# Aquaglow Lantern                                  0                   70                    0                    0 []
# Lantern                                           0                   70                    0                    0 []
# Troll's Blood                                     0                   60                    0                    0 []
# Flute                                             0                   60                    0                    0 []
# Old Rusty Key                                     0                   60                    0                    0 []
# Hardened Shell Fragment                           0                   55                    0                    0 []
# Frozen Claw                                       0                   54                    0                    0 []
# Sulfur Saliva                                     0                   52                    0                    0 []
# Patterned Gold Bangle (Perfect)                   0                   50                    0                    0 []
# Lantern                                           0                   50                    0                    0 []
# Hourglass                                         0                   50                    0                    0 []
# Saltvine                                          0                   50                    0                    0 []
# Herb Pouch                                        0                   50                    0                    0 []
# Blue Sapphire (Perfect)                           0                   50                    0                    0 []
# Gold Candle Platter (Perfect)                     0                   50                    0                    0 []
# Glimmer Bangle (Perfect)                          0                   50                    0                    0 []
# Slim Bangle (Perfect)                             0                   50                    0                    0 []
# Sealed Letter                                     0                   50                    0                    0 []
# Leaf Gold Bangle (Perfect)                        0                   50                    0                    0 []
# Triple Gem Bangle (Perfect)                       0                   50                    0                    0 []
# Silver Chalice (Exquisite)                        0                   50                    0                    0 []
# Turquoise Gem Bangle (Perfect)                    0                   50                    0                    0 []
# Dotted Gold Bangle (Perfect)                      0                   50                    0                    0 []
# Simple Gold Bangle (Perfect)                      0                   50                    0                    0 []
# Silver Ingot                                      0                   50                    0                    0 []
# Silver Ore                                        0                   50                    0                    0 []
# Silver Powder                                     0                   50                    0                    0 []
# Skinny Finger                                     0                   50                    0                    0 []
# Ghostly Essence                                   0                   50                    0                    0 []
# Gem Ring (Perfect)                                0                   50                    0                    0 []
# Blacksmith Tongs                                  0                   50                    0                    0 []
# Gem Necklace (Perfect)                            0                   50                    0                    0 []
# Firefly's Abdomen                                 0                   50                    0                    0 []
# Fabric Shears                                     0                   50                    0                    0 []
# Surgical Kit                                      0                   50                    0                    0 []
# Etched Wand Fragment                              0                   50                    0                    0 []
# Telescope                                         0                   50                    0                    0 []
# Diamond (Perfect)                                 0                   50                    0                    0 []
# Demon Blood                                       0                   50                    0                    0 []
# Wardweed                                          0                   50                    0                    0 []
# Dark Matter                                       0                   50                    0                    0 []
# Crocodilian Eyeball                               0                   50                    0                    0 []
# Ceremonial Dagger (Exquisite)                     0                   50                    0                    0 []
# Tracing Wheel                                     0                   50                    0                    0 []
# Yeti's Teeth                                      0                   50                    0                    0 []
# Captured Mana Flakes                              0                   50                    0                    0 []
# Captured Energy Flakes                            0                   50                    0                    0 []
# Campfire Kit                                      0                   50                    0                    0 []
# Broken Glasses                                    0                   50                    0                    0 []
# Volcanic Ash                                      0                   50                    0                    0 []
# Awl                                               0                   50                    0                    0 []
# Arcane Essence                                    0                   50                    0                    0 []
# Aquaglow Lantern                                  0                   50                    0                    0 []
# Phantom Flower                                    0                   50                    0                    0 []
# White Shark Tooth                                 0                   50                    0                    0 []
# Pearl Necklace (Perfect)                          0                   50                    0                    0 []
# Mermaid's Tear                                    0                   50                    0                    0 []
# Ruby (Perfect)                                    0                   50                    0                    0 []
# Lifeleaf                                          0                   50                    0                    0 []
# Leather Boot                                      0                   50                    0                    0 []
# Lava Mushroom                                     0                   50                    0                    0 []
