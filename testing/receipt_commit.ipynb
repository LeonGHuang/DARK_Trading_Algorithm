# %%
from src.database import sql

# %%
conn = sql.connect()
cursor = conn.cursor()

number,item,rarity = '3','PotionOfPotion','Epic'

number,item,rarity = '1','PhatomFlower','Rare'

query = """
    CREATE TABLE IF NOT EXIST "df"
    """
