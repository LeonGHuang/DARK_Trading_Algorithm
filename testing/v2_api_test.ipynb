# %%
import requests

url = "https://api.darkerdb.com/v2/market?key=kf_d0pv_fikkn8raodmk8q6r0883km0k4z0z7852&rarity=rare&limit=5&locale=en"
req = requests.get(url)
req = req.json()
print(req)
# Out:
# {'version': 'v0.0.51-rc.7', 'stage': 'prod', 'code': 401, 'status': 'Unauthorized', 'debug': False, 'elapsed': 0.0303, 'timestamp': '2026-07-11T02:04:33Z', 'request_id': '03ae240304d5a7cf', 'meta': {'method': 'GET', 'path': '/v2/market', 'query': {'key': 'kf_d0pv_fikkn8raodmk8q6r0883km0k4z0z7852', 'rarity': 'rare', 'limit': '5', 'locale': 'en'}}, 'flash': {'errors': [{'message': 'A valid DarkerDB API key is required for this endpoint.', 'code': 'auth:unauthenticated'}]}, 'build': '0.16.146.9064', 'patch': 71}
